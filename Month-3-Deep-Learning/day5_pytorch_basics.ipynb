# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
x = torch.tensor([2.0],requires_grad = True)
y = x ** 2

y.backward()
x.grad
# Out:
# tensor([4.])

# %%
X = torch.linspace(-1, 1, 100).view(-1, 1)
y = 2 * X + 1

# %%
class SimpleNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.hidden = nn.Linear(1,10)
        self.output = nn.Linear(10,1)

    def forward(self,x):
        x = torch.relu(self.hidden(x))
        return self.output(x)

# %%
model = SimpleNN()

criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr= 0.1)

# %%
for epoch in range(1000):
    preds = model(X)
    loss = criterion(preds,y)


    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if epoch % 100 ==0:
        print(f"Epoch {epoch}, Loss: {loss.item():.6f}")
# Out:
# Epoch 0, Loss: 4.017228
# Epoch 100, Loss: 0.002502
# Epoch 200, Loss: 0.001438
# Epoch 300, Loss: 0.001036
# Epoch 400, Loss: 0.000839
# Epoch 500, Loss: 0.000711
# Epoch 600, Loss: 0.000611
# Epoch 700, Loss: 0.000532
# Epoch 800, Loss: 0.000460
# Epoch 900, Loss: 0.000398
