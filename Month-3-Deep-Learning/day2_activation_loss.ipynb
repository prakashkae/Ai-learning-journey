# %%
import numpy as np

x = np.array([-2, -1, 0, 1, 2])

relu = np.maximum(0, x)
sigmoid = 1 / (1 + np.exp(-x))

relu, sigmoid
# Out:
# (array([0, 0, 0, 1, 2]),
#  array([0.11920292, 0.26894142, 0.5       , 0.73105858, 0.88079708]))
